# %% [markdown]
# Builtins

# %%
type(1)
# Out:
# int

# %%
__builtins__.type('Fala Galera')
# Out:
# str

# %%
import math
#a = 10 
#dir(__builtin__)
len('Ola')
# Out:
# 3

# %% [markdown]
# Built-ins são ferramentas prontas que o Python te dá de presente para você não ter que "reinventar a roda" toda vez que for programar.
