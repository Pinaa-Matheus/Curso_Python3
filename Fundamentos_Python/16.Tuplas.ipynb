# %% [markdown]
# Tuplas

# %%
dados_mat = [32, 1, 'Solteiro', 'data anl']
dados_mat
# Out:
# [32, 1, 'Solteiro', 'data anl']

# %%
dados_mat.append(1241.10)
dados_mat
# Out:
# [32, 1, 'Solteiro', 'data anl', 1241.1]

# %%
tuplas_mat = (32, 1 , 'Solteiro', 'data anl')
print(type(tuplas_mat))
print(tuplas_mat)
# Out:
# <class 'tuple'>
# (32, 1, 'Solteiro', 'data anl')

# %%
tuplas_mat[0]
# Out:
# 32

# %%
tuplas_mat[0] = 11
#Nao posso alterar nada dentro da tupla
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tuplas_mat[0] = 11
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuplas_mat = (32, 1 , 'Solteiro', 'data anl', ['Senac', 'Msul'])
#A tupla e imutal porem se tiver um objeto mutavel eu posso mudar ele 
tuplas_mat[-1].append('Mcu')
tuplas_mat
# Out:
# (32, 1, 'Solteiro', 'data anl', ['Senac', 'Msul', 'Mcu'])
