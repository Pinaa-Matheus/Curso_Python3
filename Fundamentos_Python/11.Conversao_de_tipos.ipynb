# %% [markdown]
# Conversao de Tipos

# %%
print(2 + 3)
print('2' + '2')
2 + '2'
#LEMBRE O PYTHON NUNCA VAI TENTAR ADVINHAR O QUE VOCE QUER FAZER
# Out:
# 5
# 22
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 print(2 + 3)
#       2 print('2' + '2')
# ----> 3 2 + '2'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = 3
b = '3'
print(type(a))
print(type(b))

print(a + int(b)) #Aqui transformamos uma string em int
print(str(a) + b)
# Out:
# <class 'int'>
# <class 'str'>
# 6
# 33

# %%
#POREM NAO PODEMOS CONVETER TUDO 
print(int('2 Legal'))
#Isso o python nao consegue 
print(int('3.2')) #Isso a gente nao pode conveter 
print(float(3.4)) #Porem isso a gente consegue

# %% [markdown]
# Coerção Automática

# %%
10 / 2
type(10 / 2)
#Aqui o python ele mudou o tipo da variavel, isso em algumas linguagem nao e possivel
#Em Java sempre que tem uma divisao de dois numeros interios sempre vai dar uma um resultado inteiro
10 // 3
# Out:
# 3

# %%
10 // 3.3 
type(10 // 3.3)
#Aqui ele da um float pq o float consegue amazenar mais numeros porem como estamos fazendo uma diviasao interia ele zera o primeiro numero
# Out:
# 3.0
