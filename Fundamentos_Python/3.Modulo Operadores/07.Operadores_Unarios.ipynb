# %% [markdown]
# Operadores Unarios

# %%
a = 3
# a++  (Isso nao e possivel em python ja em outras linguagem isso e possivel)
a += 1 
print(a)
# Out:
# 4

# %%
a = -3 
+a 
# Voce pode esta falando porque ele nao virou um numero positivo, porem voce nao atribuiu nada a variavel a
print(a)
# Out:
# -3
