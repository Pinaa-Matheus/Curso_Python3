# %%
# Trabalhos]
trabalhos_terca = True
trabalhos_quinta = False 

"""
- Confirmado os 2: Tv 50` + Soverte 
- Confirmado aprenas 1: Tv 32` + Soverte 
- Nenhum confirmado : Ficar em casa
"""

tv_50 = trabalhos_terca and trabalhos_quinta
soverte = trabalhos_quinta or trabalhos_terca
tv_32 = trabalhos_terca != trabalhos_quinta #xor
mais_saudavel = not soverte

print(f'Tv50={tv_50} Tv32={tv_32} sorvete={soverte} saudavel={mais_saudavel}')
# Out:
# Tv50=False Tv32=True sorvete=True saudavel=False
